# %% [markdown]
# <a href="https://colab.research.google.com/github/mengyaoo/FNL_GenesSelection/blob/main/02_TC1_PCA%26tSNE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the libraries

# %%
from __future__ import print_function

import os, sys, gzip, glob, json, time, argparse
import pandas as pd
import numpy as np
import keras
from pandas.io.json import json_normalize

from pandas.io.json import json_normalize
from keras.utils import to_categorical
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from keras.utils import to_categorical
from keras import backend as K
from keras.layers import Input, Dense, Dropout, Activation, Conv1D, MaxPooling1D, Flatten
from keras import optimizers
from keras.optimizers import SGD, Adam, RMSprop
from keras.models import Sequential, Model, model_from_json, model_from_yaml
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau

from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import sklearn.manifold as sk_manif
from keras.models import model_from_json
from keras.utils import to_categorical

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Preparation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read features and output files 
TC1data15 = pd.read_csv("/content/drive/My Drive/FNL_TC1/TC1-S1-data15-genename.tsv", sep="\t", low_memory = False)
#TC1data15 = sfeatures1
TC1data15
# Out:
#         TSPAN6      TNMD      DPM1  ...  MIR6089.1  RP13-465B17.5.1  RP13-465B17.4.1
# 0     1.829525  0.000000  2.062846  ...        0.0              0.0              0.0
# 1     1.541309  0.000000  1.815986  ...        0.0              0.0              0.0
# 2     1.282789  0.000000  1.895928  ...        0.0              0.0              0.0
# 3     1.388260  0.000000  1.905475  ...        0.0              0.0              0.0
# 4     1.389160  0.530588  2.316735  ...        0.0              0.0              0.0
# ...        ...       ...       ...  ...        ...              ...              ...
# 4495  1.897300  0.000000  1.829995  ...        0.0              0.0              0.0
# 4496  1.740598  0.000000  1.711895  ...        0.0              0.0              0.0
# 4497  1.586418  0.000000  1.628429  ...        0.0              0.0              0.0
# 4498  2.218943  0.093382  1.762568  ...        0.0              0.0              0.0
# 4499  1.497944  0.000000  1.855045  ...        0.0              0.0              0.0
#
# [4500 rows x 60483 columns]

# %%
outcome = pd.read_csv('/content/drive/My Drive/FNL_TC1/TC1-outcome-data15-projectname.tsv', sep='\t')
outcome
# Out:
#      Project_id_name  Project_id
# 0            TCGA-OV          10
# 1            TCGA-OV          10
# 2            TCGA-OV          10
# 3            TCGA-OV          10
# 4            TCGA-OV          10
# ...              ...         ...
# 4495       TCGA-LIHC           7
# 4496       TCGA-LIHC           7
# 4497       TCGA-LIHC           7
# 4498       TCGA-LIHC           7
# 4499       TCGA-CESC           2
#
# [4500 rows x 2 columns]

# %%
#outcome = outcome.values
#outcome = outcome['Project_id_name']

# %%
def encode(data): 
    print('Shape of data (BEFORE encode): %s' % str(data.shape))
    encoded = to_categorical(data)
    print('Shape of data (AFTER  encode): %s\n' % str(encoded.shape))
    return encoded

# %% [markdown]
# # Feature Selection(PCA) + t-SNE

# %%
import importlib
from google.colab import files
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/My Drive/FNL_TC1')
import tc1_library
importlib.reload(tc1_library);
import sklearn.decomposition as sk_decomp
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# * add label for plot
# * what can we learn from the figure from the groups that are overlap, are these related with each other

# %%
def plot_unsupervised_learning_results(unsupervised_learning_results, labels):
	'''
	Plot results from unsupervised learning analyses such as PCA or tSNE, overplotting the color/style of the markers based on known labels.
	'''

	# Import relevant libraries
	import seaborn as sns
	import matplotlib.pyplot as plt
	import matplotlib.lines as mpl_lines

	# Get a reasonable set of markers and color palette
	markers = mpl_lines.Line2D.filled_markers
	nclasses = len(set(labels))
	marker_list = (markers * int(nclasses/len(markers)+1))[:nclasses]
	color_palette = sns.color_palette("hls", nclasses)

	# Plot results
	_, ax = plt.subplots(figsize=(12,7.5), facecolor='w')
	ax = sns.scatterplot(x=unsupervised_learning_results[:,0], y=unsupervised_learning_results[:,1], hue=labels, style=labels, palette=color_palette, legend='full', alpha=1, markers=marker_list, edgecolor='k', ax=ax)
	ax.legend(bbox_to_anchor=(1,1))
	return(ax)


def run_and_plot_pca_and_tsne(X, y, top_n_features=500):
	'''
	Run PCA and tSNE analyses on data X and plot the results with marker color/style by known labels y.
	Note that tSNE takes long if using many features, so for tSNE we use the top-top_n_features-variance genes.
	'''

	# Sort the features by decreasing variance
	X_by_variance = X.loc[:,[x for x in X.var().sort_values(ascending=False).index]]

	# Perform the PCA using scikit-learn
	import sklearn.decomposition as sk_decomp
	pca = sk_decomp.PCA(n_components=10)
	pca_results = pca.fit_transform(X_by_variance)
	print('Top {} PCA explained variance ratios: {}'.format(10, pca.explained_variance_ratio_))
	ax = plot_unsupervised_learning_results(pca_results, y)
	ax.set_title('PCA')

	# Perform tSNE using scikit-learn
	import sklearn.manifold as sk_manif
	tsne = sk_manif.TSNE(n_components=2)
	tsne_results = tsne.fit_transform(X_by_variance.iloc[:,:top_n_features])
	ax = plot_unsupervised_learning_results(tsne_results, y)
	ax.set_title('tSNE (using top-{}-variance features)'.format(top_n_features))

# %%
id_name = outcome.drop_duplicates().sort_values('Project_id')['Project_id_name']
id_name = list(id_name)

# %%
run_and_plot_pca_and_tsne(TC1data15, outcome['Project_id_name'])
# Out:
# Top 10 PCA explained variance ratios: [0.11951665 0.10788788 0.05949288 0.05309376 0.04052011 0.03719555
#  0.02759182 0.02507799 0.02285892 0.01953212]

# %% [markdown]
# ## PCA

# %% [markdown]
# The loadings describe how much each variable contributes to a particular principal component. Large loadings (positive or negative) indicate that a particular variable has a strong relationship to a particular principal component. The sign of a loading indicates whether a variable and a principal component are positively or negatively correlated.

# %%
# TC1data15.columns = TC1data15_names

# %%
np.random.seed(123)
pca = PCA(0.95)
pca_results = pca.fit_transform(TC1data15)

# %%
loadings = pd.DataFrame(pca.components_.T, index=TC1data15.columns)
loadings
# Out:
#                      0         1         2     ...      1943      1944      1945
# TSPAN6           0.001059 -0.000904  0.000494  ... -0.006800 -0.006220  0.003201
# TNMD            -0.000056 -0.000431  0.002453  ...  0.003262  0.005443 -0.000905
# DPM1            -0.004084 -0.005749 -0.001141  ... -0.001602  0.001822  0.002236
# SCYL3            0.001336 -0.006378  0.003935  ... -0.005248 -0.001807 -0.003160
# C1orf112        -0.006355 -0.008396 -0.004065  ... -0.004270  0.001624  0.001096
# ...                   ...       ...       ...  ...       ...       ...       ...
# Metazoa_SRP.305 -0.000000 -0.000000  0.000000  ...  0.000000 -0.000000 -0.000000
# AJ271736.1.1    -0.000000 -0.000000  0.000000  ...  0.000000 -0.000000 -0.000000
# MIR6089.1       -0.000000 -0.000000  0.000000  ...  0.000000 -0.000000 -0.000000
# RP13-465B17.5.1 -0.000000 -0.000000  0.000000  ...  0.000000 -0.000000 -0.000000
# RP13-465B17.4.1 -0.000000 -0.000000  0.000000  ...  0.000000 -0.000000 -0.000000
#
# [60483 rows x 1946 columns]

# %%
abs_loading = loadings.abs()

# %%
sum_loading = abs_loading.sum(axis=1)

# %%
sum_loading
# Out:
# TSPAN6             9.132597
# TNMD               9.486756
# DPM1               4.374390
# SCYL3              4.672492
# C1orf112           6.018668
#                      ...
# Metazoa_SRP.305    0.000000
# AJ271736.1.1       0.000000
# MIR6089.1          0.000000
# RP13-465B17.5.1    0.000000
# RP13-465B17.4.1    0.000000
# Length: 60483, dtype: float64

# %%
sum(sum_loading >= 15)
# Out:
# 1883

# %%
sum_loading.loc[sum_loading >= 15,]
# Out:
# CFTR             18.118817
# AOC1             23.661325
# CYP26B1          16.386817
# TFPI             16.266705
# SLC7A2           19.858020
#                    ...
# RP5-1180D12.1    15.184301
# IGHV1-69-2       19.893650
# AC024896.1       15.716745
# AC055866.1       18.089839
# AC091180.1       16.049877
# Length: 1883, dtype: float64

# %% [markdown]
# ## t-SNE

# %%
#X_by_variance = TC1data15.iloc[:,[int(x) for x in TC1data15.var().sort_values(ascending=False).index]]

#tsne = TSNE(n_components=2)
#tsne_results = tsne.fit_transform(X_by_variance.iloc[:,:500])

# TC1data15.columns = list(range(0, TC1data15.shape[1]))

# %%
# removes features that their variances are lower than 0.3
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=(0.3))
sel_by_var = sel.fit_transform(TC1data15)

# %%
TC1data15.shape, sel_by_var.shape
# Out:
# ((4500, 60483), (4500, 1830))

# %%
tsne = TSNE(n_components=2)
tsne_results = tsne.fit_transform(sel_by_var)

# %%
a = pd.DataFrame(tsne_results,columns=['x','y']) 
a['Project_id_name'] = outcome['Project_id_name']
x_y = a.groupby(['Project_id_name']).mean()

# %%
x_y = x_y.reset_index()

# %%
ax = plot_unsupervised_learning_results(tsne_results, outcome['Project_id_name'])

ax.set_title('tSNE (using top-{}-variance features)'.format(sel_by_var.shape[1]))
for i in x_y.index:
  ax.text(x_y.loc[i,'x'],x_y.loc[i,'y'],x_y.loc[i,'Project_id_name'],fontsize=12,fontweight = 'bold')

# %% [markdown]
# # ConvNN(PCA) - Top129

# %%
outcome = encode(outcome['Project_id'])
# outcome = np.expand_dims(outcome, axis=2)
# outcome[0].value_counts()

# %% [markdown]
# ## Train/Test split

# %%
TC1data15_selected = TC1data15.loc[:,sum_loading.sort_values(ascending=False)[:129].index]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(TC1data15_selected, 
                                                    outcome, 
                                                    train_size=0.75, 
                                                    test_size=0.25, 
                                                    random_state=123, 
                                                    stratify = outcome)

# %% [markdown]
# ## CONV1D

# %%
# parameters  
activation='relu'
batch_size=20
# Number of sites
classes=15
drop = 0.1
feature_subsample = 0
loss='categorical_crossentropy'
# metrics='accuracy'
out_act='softmax'
pool=[1, 10]
# optimizer='sgd'
shuffle = False 
epochs=100

optimizer = optimizers.SGD(lr=0.1)
metrics = ['acc']

# %%
np.expand_dims(X_train, axis=2).shape
# Out:
# (3375, 129, 1)

# %%
# X_train shape: (3375, 1883)
# X_test shape:  (1125, 1883)
# Y_train shape: (3375,15)
# Y_test shape:  (1125,15)

# 1883
x_train_len = X_train.shape[1]   

X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# X_train shape: (3375, 1883, 1)
# X_test shape:  (1125, 1883, 1)

filters = 128 
filter_len = 20 
stride = 1 

# inside pool_list loop
pool_list = [1,10]

K.clear_session()

model = Sequential()

# model.add  CONV1D
model.add(Conv1D(filters = filters, 
                 kernel_size = filter_len, 
                 strides = stride, 
                 padding='valid', 
                 input_shape=(x_train_len, 1)))

# x_train_len = 60,483
# Activation
model.add(Activation('relu'))

# MaxPooling
model.add(MaxPooling1D(pool_size = 1))

filters = 128
filter_len = 10 
stride = 1 
# Conv1D
model.add(Conv1D(filters=filters, 
                 kernel_size=filter_len, 
                 strides=stride, 
                 padding='valid'))
# Activation
model.add(Activation('relu'))

# MaxPooling
model.add(MaxPooling1D(pool_size = 10))
model.add(Flatten())

model.add(Dense(200))

# activation 
# model.add(Activation('relu')) # SR
model.add(Activation(activation))
#dropout
model.add(Dropout(0.1))

model.add(Dense(20))
# activation
# model.add(Activation('relu')) # SR
model.add(Activation(activation))

#dropout
model.add(Dropout(0.1))

model.add(Dense(15))
model.add(Activation(out_act))

model.compile( loss= loss, 
              optimizer = optimizer, 
              metrics = metrics )
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 110, 128)          2688
# _________________________________________________________________
# activation (Activation)      (None, 110, 128)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 110, 128)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 101, 128)          163968
# _________________________________________________________________
# activation_1 (Activation)    (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 200)               256200
# _________________________________________________________________
# activation_2 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                4020
# _________________________________________________________________
# activation_3 (Activation)    (None, 20)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                315
# _________________________________________________________________
# activation_4 (Activation)    (None, 15)                0
# =================================================================
# Total params: 427,191
# Trainable params: 427,191
# Non-trainable params: 0
# _________________________________________________________________

# %%
# save
save = '.'
output_dir = "/content/drive/My Drive/FNL_TC1/Model"

if not os.path.exists(output_dir):
        os.makedirs(output_dir)

model_name = 'tc1_pca129'
path = '{}/{}.autosave.model.h5'.format(output_dir, model_name)
checkpointer = ModelCheckpoint(filepath=path,
                               verbose=1,
                               save_weights_only=True,
                               save_best_only=True)

csv_logger = CSVLogger('{}/training.log'.format(output_dir))

# %%
# SR: change epsilon to min_delta
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.1, 
                              patience=10, 
                              verbose=1, mode='auto', 
                              min_delta=0.0001, 
                              cooldown=0, 
                              min_lr=0)

# %%
# batch_size = 20 
history = model.fit(X_train, Y_train, batch_size=batch_size, 
                    epochs=epochs, verbose=1, validation_data=(X_test, Y_test), 
                    callbacks = [checkpointer, csv_logger, reduce_lr])

score = model.evaluate(X_test, Y_test, verbose=0)
# Out:
# Epoch 1/100
# 169/169 [==============================] - ETA: 0s - loss: 1.8833 - acc: 0.3896
# Epoch 00001: val_loss improved from inf to 0.89242, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca129.autosave.model.h5
# 169/169 [==============================] - 7s 39ms/step - loss: 1.8833 - acc: 0.3896 - val_loss: 0.8924 - val_acc: 0.6969
# Epoch 2/100
# 169/169 [==============================] - ETA: 0s - loss: 0.6259 - acc: 0.8036
# Epoch 00002: val_loss improved from 0.89242 to 0.38735, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_p
- val_loss: 0.3697 - val_acc: 0.9333
# Epoch 93/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0072 - acc: 0.9979
# Epoch 00093: val_loss did not improve from 0.27824
# 169/169 [==============================] - 6s 38ms/step - loss: 0.0072 - acc: 0.9979 - val_loss: 0.3697 - val_acc: 0.9333
# Epoch 94/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0069 - acc: 0.9985
# Epoch 00094: val_loss did not improve from 0.27824
# 169/169 [==============================] - 6s 38ms/step - loss: 0.0069 - acc: 0.9985 - val_loss: 0.3697 - val_acc: 0.9333
# Epoch 95/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0119 - acc: 0.9970
# Epoch 00095: val_loss did not improve from 0.27824
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 9.999998606957661e-11.
# 169/169 [==============================] - 6s 37ms/step - loss: 0.0119 - acc: 0.9970 - val_loss: 0.3697 - val_acc: 0.9333
# Epoch 96/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0100 - acc: 0.9967
# Epoch 00096: val_loss did not improve from 0.27824
# 169/169 [==============================] - 6s 37ms/step - loss: 0.0100 - acc: 0.9967 - val_loss: 0.3697 - val_acc: 0.9333
# Epoch 97/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0094 - acc: 0.9970
# Epoch 00097: val_loss did not improve from 0.27824
# 169/169 [==============================] - 6s 37ms/step - loss: 0.0094 - acc: 0.9970 - val_loss: 0.3697 - val_acc: 0.9333
# Epoch 98/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0093 - acc: 0.9973
# Epoch 00098: val_loss did not improve from 0.27824
# 169/169 [==============================] - 6s 37ms/step - loss: 0.0093 - acc: 0.9973 - val_loss: 0.3697 - val_acc: 0.9333
# Epoch 99/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0097 - acc: 0.9979
# Epoch 00099: val_loss did not improve from 0.27824
# 169/169 [==============================] - 6s 37ms/step - loss: 0.0097 - acc: 0.9979 - val_loss: 0.3697 - val_acc: 0.9333
# Epoch 100/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0078 - acc: 0.9979
# Epoch 00100: val_loss did not improve from 0.27824
# 169/169 [==============================] - 6s 38ms/step - loss: 0.0078 - acc: 0.9979 - val_loss: 0.3697 - val_acc: 0.9333

# %%
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.3696829676628113
# Test accuracy: 0.9333333373069763

# %%
plt.plot(history.history['acc'],label="accuracy")
plt.plot(history.history['val_acc'],label="val_accuracy")
plt.plot(history.history['loss'],label="loss")
plt.plot(history.history['val_loss'],label="val_loss")
plt.legend()
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %% [markdown]
# ## Save the model/weights

# %%
# JSON JSON
# serialize model to json
json_model = model.to_json()

# save the model architecture to JSON file
with open('{}/{}.model.json'.format(output_dir, model_name), 'w') as json_file:
    json_file.write(json_model)


# YAML YAML
# serialize model to YAML
model_yaml = model.to_yaml()

# save the model architecture to YAML file
with open("{}/{}.model.yaml".format(output_dir, model_name), "w") as yaml_file:
    yaml_file.write(model_yaml)


# WEIGHTS HDF5
# serialize weights to HDF5
model.save_weights("{}/{}.model.h5".format(output_dir,model_name))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Open the handle
json_file = open('{}/{}.model.json'.format(output_dir, model_name), 'r')

# load json and create model
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights('{}/{}.model.h5'.format(output_dir, model_name))
print("Loaded model from disk")
# loaded_model_json
# Out:
# Loaded model from disk

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer='sgd', 
                     metrics=['accuracy'])
score = loaded_model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])

print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Test score: 0.3696829676628113
# Test accuracy: 0.9333333373069763
# accuracy: 93.33%

# %% [markdown]
# # ConvNN(PCA) - top 300

# %% [markdown]
# ## Train/Test split

# %%
# from keras.utils import to_categorical
# outcome = encode(outcome['Project_id'])

# %%
TC1data15_selected = TC1data15.loc[:,sum_loading.sort_values(ascending=False)[:300].index]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(TC1data15_selected, 
                                                    outcome, 
                                                    train_size=0.75, 
                                                    test_size=0.25, 
                                                    random_state=123, 
                                                    stratify = outcome)

# %%
X_train
# Out:
#          OLFM4      IGHD      CST1  ...     GPAT2  CTA-384D8.31     VTCN1
# 849   0.000000  3.451720  1.924427  ...  0.000000      0.143028  0.685608
# 1050  0.000000  0.891166  0.070649  ...  0.000000      2.269779  2.263385
# 835   0.000000  1.241689  2.417806  ...  0.000000      0.000000  1.764685
# 4447  0.000000  0.314609  2.389053  ...  0.000000      0.000000  0.516333
# 53    0.000000  0.124001  0.848674  ...  0.000000      1.271739  2.542553
# ...        ...       ...       ...  ...       ...           ...       ...
# 3495  1.425760  0.050455  0.000000  ...  0.063402      2.016462  0.503991
# 1737  0.000000  1.129846  0.000000  ...  0.147774      0.000000  0.000000
# 2943  1.890701  1.294848  0.000000  ...  0.849848      2.097353  0.590774
# 1573  0.000000  0.921816  0.000000  ...  0.135691      0.000000  2.960005
# 3192  0.000000  0.000000  0.000000  ...  0.032800      0.734222  0.595237
#
# [3375 rows x 300 columns]

# %% [markdown]
# ## CONV1D

# %%
# parameters  
activation='relu'
batch_size=20
# Number of sites
classes=15
drop = 0.1
feature_subsample = 0
loss='categorical_crossentropy'
# metrics='accuracy'
out_act='softmax'
pool=[1, 10]
# optimizer='sgd'
shuffle = False 
epochs=100

optimizer = optimizers.SGD(lr=0.1)
metrics = ['acc']

# %%
# X_train shape: (3375, 300)
# X_test shape:  (1125, 300)
# Y_train shape: (3375,15)
# Y_test shape:  (1125,15)

# 300
x_train_len = X_train.shape[1]   

X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# X_train shape: (3375, 300, 1)
# X_test shape:  (1125, 300, 1)

filters = 128 
filter_len = 20 
stride = 1 

# inside pool_list loop
pool_list = [1,10]

K.clear_session()

# %%
model = Sequential()

# model.add  CONV1D
model.add(Conv1D(filters = filters, 
                 kernel_size = filter_len, 
                 strides = stride, 
                 padding='valid', 
                 input_shape=(x_train_len, 1)))

# x_train_len = 300
# Activation
model.add(Activation('relu'))

# MaxPooling
model.add(MaxPooling1D(pool_size = 1))

filters = 128
filter_len = 10 
stride = 1 
# Conv1D
model.add(Conv1D(filters=filters, 
                 kernel_size=filter_len, 
                 strides=stride, 
                 padding='valid'))
# Activation
model.add(Activation('relu'))

# MaxPooling
model.add(MaxPooling1D(pool_size = 10))
model.add(Flatten())

model.add(Dense(200))

# activation 
# model.add(Activation('relu')) # SR
model.add(Activation(activation))
#dropout
model.add(Dropout(0.1))

model.add(Dense(20))
# activation
# model.add(Activation('relu')) # SR
model.add(Activation(activation))

#dropout
model.add(Dropout(0.1))

model.add(Dense(15))
model.add(Activation(out_act))

model.compile( loss= loss, 
              optimizer = optimizer, 
              metrics = metrics )
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 281, 128)          2688
# _________________________________________________________________
# activation (Activation)      (None, 281, 128)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 281, 128)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 272, 128)          163968
# _________________________________________________________________
# activation_1 (Activation)    (None, 272, 128)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 27, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 3456)              0
# _________________________________________________________________
# dense (Dense)                (None, 200)               691400
# _________________________________________________________________
# activation_2 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                4020
# _________________________________________________________________
# activation_3 (Activation)    (None, 20)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                315
# _________________________________________________________________
# activation_4 (Activation)    (None, 15)                0
# =================================================================
# Total params: 862,391
# Trainable params: 862,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
# save
# save = '/content/drive/My Drive/FNL_TC1/'
output_dir = "/content/drive/My Drive/FNL_TC1/Model"

if not os.path.exists(output_dir):
        os.makedirs(output_dir)

model_name = 'tc1_pca300'
path = '{}/{}.autosave.model.h5'.format(output_dir, model_name)
checkpointer = ModelCheckpoint(filepath=path,
                               verbose=1,
                               save_weights_only=True,
                               save_best_only=True)

csv_logger = CSVLogger('{}/training.log'.format(output_dir))

# %%
# SR: change epsilon to min_delta
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.1, 
                              patience=10, 
                              verbose=1, mode='auto', 
                              min_delta=0.0001, 
                              cooldown=0, 
                              min_lr=0)

# %%
# batch_size = 20 
history = model.fit(X_train, Y_train, batch_size=batch_size, 
                    epochs=epochs, verbose=1, validation_data=(X_test, Y_test), 
                    callbacks = [checkpointer, csv_logger, reduce_lr])

score = model.evaluate(X_test, Y_test, verbose=0)
# Out:
# Epoch 1/100
# 169/169 [==============================] - ETA: 0s - loss: 1.7414 - acc: 0.4353
# Epoch 00001: val_loss improved from inf to 0.68599, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca300.autosave.model.h5
# 169/169 [==============================] - 14s 81ms/step - loss: 1.7414 - acc: 0.4353 - val_loss: 0.6860 - val_acc: 0.7467
# Epoch 2/100
# 169/169 [==============================] - ETA: 0s - loss: 0.4949 - acc: 0.8290
# Epoch 00002: val_loss improved from 0.68599 to 0.34481, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca300.autosave.model.h5
# 169/169 [==============================] - 13s 80ms/step - loss: 0.4949 - acc: 0.8290 - val_loss: 0.3448 - val_acc: 0.8987
# Epoch 3/100
# 169/169 [==============================] - ETA: 0s - loss: 0.2742 - acc: 0.9132
# Epoch 00003: val_loss improved from 0.34481 to 0.26304, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca300.autosave.model.h5
# 169/169 [==============================] - 13s 80ms/step - loss: 0.2742 - acc: 0.9132 - val_loss: 0.2630 - val_acc: 0.9164
# Epoch 4/100
# 169/169 [==============================] - ETA: 0s - loss: 0.1859 - acc: 0.9378
# Epoch 00004: val_loss did not improve from 0.26304
# 169/169 [==============================] - 13s 78ms/step - loss: 0.1859 - acc: 0.9378 - val_loss: 0.2818 - val_acc: 0.9227
# Epoch 5/100
# 169/169 [==============================] - ETA: 0s - loss: 0.1330 - acc: 0.9535
# Epoch 00005: val_loss improved from 0.26304 to 0.22779, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca300.autosave.model.h5
# 169/169 [==============================] - 14s 80ms/step - loss: 0.1330 - acc: 0.9535 - val_loss: 0.2278 - val_acc: 0.9262
# Epoch 6/100
# 169/169 [==============================] - ETA: 0s - loss: 0.1012 - acc: 0.9695
# Epoch 00006: val_loss improved from 0.22779 to 0.20770, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca300.autosave.model.h5
# 169/169 [==============================] - 13s 79ms/step - loss: 0.1012 - acc: 0.9695 - val_loss: 0.2077 - val_acc: 0.9404
# Epoch 7/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0641 - acc: 0.9810
# Epoch 00007: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0641 - acc: 0.9810 - val_loss: 0.3530 - val_acc: 0.8916
# Epoch 8/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0440 - acc: 0.9861
# Epoch 00008: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0440 - acc: 0.9861 - val_loss: 0.2888 - val_acc: 0.9387
# Epoch 9/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0521 - acc: 0.9834
# Epoch 00009: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0521 - acc: 0.9834 - val_loss: 0.2594 - val_acc: 0.9413
# Epoch 10/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0249 - acc: 0.9914
# Epoch 00010: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 77ms/step - loss: 0.0249 - acc: 0.9914 - val_loss: 0.3205 - val_acc: 0.9316
# Epoch 11/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0352 - acc: 0.9876
# Epoch 00011: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0352 - acc: 0.9876 - val_loss: 0.2212 - val_acc: 0.9556
# Epoch 12/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0299 - acc: 0.9893
# Epoch 00012: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0299 - acc: 0.9893 - val_loss: 0.2680 - val_acc: 0.9484
# Epoch 13/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0175 - acc: 0.9938
# Epoch 00013: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0175 - acc: 0.9938 - val_loss: 0.2735 - val_acc: 0.9440
# Epoch 14/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0225 - acc: 0.9920
# Epoch 00014: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0225 - acc: 0.9920 - val_loss: 0.2988 - val_acc: 0.9467
# Epoch 15/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0262 - acc: 0.9926
# Epoch 00015: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 78ms/step - loss: 0.0262 - acc: 0.9926 - val_loss: 0.2646 - val_acc: 0.9538
# Epoch 16/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0183 - acc: 0.
- acc: 0.9982 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 91/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0099 - acc: 0.9967
# Epoch 00091: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0099 - acc: 0.9967 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 92/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0083 - acc: 0.9979
# Epoch 00092: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0083 - acc: 0.9979 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 93/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0065 - acc: 0.9982
# Epoch 00093: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0065 - acc: 0.9982 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 94/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0056 - acc: 0.9985
# Epoch 00094: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 80ms/step - loss: 0.0056 - acc: 0.9985 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 95/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.9979
# Epoch 00095: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0061 - acc: 0.9979 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 96/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0066 - acc: 0.9979
# Epoch 00096: val_loss did not improve from 0.20770
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 9.999998606957661e-11.
# 169/169 [==============================] - 14s 80ms/step - loss: 0.0066 - acc: 0.9979 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 97/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0052 - acc: 0.9988
# Epoch 00097: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0052 - acc: 0.9988 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 98/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0069 - acc: 0.9979
# Epoch 00098: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0069 - acc: 0.9979 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 99/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0036 - acc: 0.9988
# Epoch 00099: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0036 - acc: 0.9988 - val_loss: 0.2916 - val_acc: 0.9564
# Epoch 100/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0064 - acc: 0.9982
# Epoch 00100: val_loss did not improve from 0.20770
# 169/169 [==============================] - 13s 79ms/step - loss: 0.0064 - acc: 0.9982 - val_loss: 0.2916 - val_acc: 0.9564

# %%
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.29160013794898987
# Test accuracy: 0.9564444422721863

# %%
plt.plot(history.history['acc'],label="accuracy")
plt.plot(history.history['val_acc'],label="val_accuracy")
plt.plot(history.history['loss'],label="loss")
plt.plot(history.history['val_loss'],label="val_loss")
plt.legend()
plt.title("Top 300 features")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %% [markdown]
# ## Save the model/weights

# %%
# JSON JSON
# serialize model to json
json_model = model.to_json()

# save the model architecture to JSON file
with open('{}/{}.model.json'.format(output_dir, model_name), 'w') as json_file:
    json_file.write(json_model)


# YAML YAML
# serialize model to YAML
model_yaml = model.to_yaml()

# save the model architecture to YAML file
with open("{}/{}.model.yaml".format(output_dir, model_name), "w") as yaml_file:
    yaml_file.write(model_yaml)


# WEIGHTS HDF5
# serialize weights to HDF5
model.save_weights("{}/{}.model.h5".format(output_dir,model_name))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Open the handle
json_file = open('{}/{}.model.json'.format(output_dir, model_name), 'r')

# load json and create model
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights('{}/{}.model.h5'.format(output_dir, model_name))
print("Loaded model from disk")
# loaded_model_json
# Out:
# Loaded model from disk

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer='sgd', 
                     metrics=['accuracy'])
score = loaded_model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])

print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Test score: 0.29160013794898987
# Test accuracy: 0.9564444422721863
# accuracy: 95.64%

# %% [markdown]
# # ConvNN(PCA) - top 518

# %% [markdown]
# ## Train/Test split

# %%
# from keras.utils import to_categorical
# outcome = encode(outcome['Project_id'])

# %%
TC1data15_selected = TC1data15.loc[:,sum_loading.sort_values(ascending=False)[:518].index]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(TC1data15_selected, 
                                                    outcome, 
                                                    train_size=0.75, 
                                                    test_size=0.25, 
                                                    random_state=123, 
                                                    stratify = outcome)

# %%
X_train
# Out:
#          OLFM4      IGHD      CST1  ...  GP2    ALPPL2  RP11-834C11.4
# 849   0.000000  3.451720  1.924427  ...  0.0  1.782939       0.928844
# 1050  0.000000  0.891166  0.070649  ...  0.0  0.000000       0.521634
# 835   0.000000  1.241689  2.417806  ...  0.0  0.000000       1.037705
# 4447  0.000000  0.314609  2.389053  ...  0.0  0.000000       1.012753
# 53    0.000000  0.124001  0.848674  ...  0.0  0.061475       1.456874
# ...        ...       ...       ...  ...  ...       ...            ...
# 3495  1.425760  0.050455  0.000000  ...  0.0  0.000000       0.279165
# 1737  0.000000  1.129846  0.000000  ...  0.0  0.000000       0.886067
# 2943  1.890701  1.294848  0.000000  ...  0.0  0.000000       0.970292
# 1573  0.000000  0.921816  0.000000  ...  0.0  0.114988       1.359932
# 3192  0.000000  0.000000  0.000000  ...  0.0  0.000000       0.890628
#
# [3375 rows x 518 columns]

# %% [markdown]
# ## CONV1D

# %%
# parameters  
activation='relu'
batch_size=20
# Number of sites
classes=15
drop = 0.1
feature_subsample = 0
loss='categorical_crossentropy'
# metrics='accuracy'
out_act='softmax'
pool=[1, 10]
# optimizer='sgd'
shuffle = False 
epochs=100

optimizer = optimizers.SGD(lr=0.1)
metrics = ['acc']

# %%
# X_train shape: (3375, 300)
# X_test shape:  (1125, 300)
# Y_train shape: (3375,15)
# Y_test shape:  (1125,15)

# 300
x_train_len = X_train.shape[1]   

X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# X_train shape: (3375, 300, 1)
# X_test shape:  (1125, 300, 1)

filters = 128 
filter_len = 20 
stride = 1 

# inside pool_list loop
pool_list = [1,10]

K.clear_session()

# %%
model = Sequential()

# model.add  CONV1D
model.add(Conv1D(filters = filters, 
                 kernel_size = filter_len, 
                 strides = stride, 
                 padding='valid', 
                 input_shape=(x_train_len, 1)))

# x_train_len = 300
# Activation
model.add(Activation('relu'))

# MaxPooling
model.add(MaxPooling1D(pool_size = 1))

filters = 128
filter_len = 10 
stride = 1 
# Conv1D
model.add(Conv1D(filters=filters, 
                 kernel_size=filter_len, 
                 strides=stride, 
                 padding='valid'))
# Activation
model.add(Activation('relu'))

# MaxPooling
model.add(MaxPooling1D(pool_size = 10))
model.add(Flatten())

model.add(Dense(200))

# activation 
# model.add(Activation('relu')) # SR
model.add(Activation(activation))
#dropout
model.add(Dropout(0.1))

model.add(Dense(20))
# activation
# model.add(Activation('relu')) # SR
model.add(Activation(activation))

#dropout
model.add(Dropout(0.1))

model.add(Dense(15))
model.add(Activation(out_act))

model.compile( loss= loss, 
              optimizer = optimizer, 
              metrics = metrics )
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 499, 128)          2688
# _________________________________________________________________
# activation (Activation)      (None, 499, 128)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 499, 128)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 490, 128)          163968
# _________________________________________________________________
# activation_1 (Activation)    (None, 490, 128)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 49, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 200)               1254600
# _________________________________________________________________
# activation_2 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                4020
# _________________________________________________________________
# activation_3 (Activation)    (None, 20)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                315
# _________________________________________________________________
# activation_4 (Activation)    (None, 15)                0
# =================================================================
# Total params: 1,425,591
# Trainable params: 1,425,591
# Non-trainable params: 0
# _________________________________________________________________

# %%
# save
# save = '/content/drive/My Drive/FNL_TC1/'
output_dir = "/content/drive/My Drive/FNL_TC1/Model"

if not os.path.exists(output_dir):
        os.makedirs(output_dir)

model_name = 'tc1_pca518'
path = '{}/{}.autosave.model.h5'.format(output_dir, model_name)
checkpointer = ModelCheckpoint(filepath=path,
                               verbose=1,
                               save_weights_only=True,
                               save_best_only=True)

csv_logger = CSVLogger('{}/training.log'.format(output_dir))

# %%
# SR: change epsilon to min_delta
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.1, 
                              patience=10, 
                              verbose=1, mode='auto', 
                              min_delta=0.0001, 
                              cooldown=0, 
                              min_lr=0)

# %%
# batch_size = 20 
history = model.fit(X_train, Y_train, batch_size=batch_size, 
                    epochs=epochs, verbose=1, validation_data=(X_test, Y_test), 
                    callbacks = [checkpointer, csv_logger, reduce_lr])

score = model.evaluate(X_test, Y_test, verbose=0)
# Out:
# Epoch 1/100
# 169/169 [==============================] - ETA: 0s - loss: 1.6898 - acc: 0.4634
# Epoch 00001: val_loss improved from inf to 0.50568, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca518.autosave.model.h5
# 169/169 [==============================] - 22s 132ms/step - loss: 1.6898 - acc: 0.4634 - val_loss: 0.5057 - val_acc: 0.8329
# Epoch 2/100
# 169/169 [==============================] - ETA: 0s - loss: 0.4262 - acc: 0.8643
# Epoch 00002: val_loss improved from 0.50568 to 0.27718, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca518.autosave.model.h5
# 169/169 [==============================] - 22s 131ms/step - loss: 0.4262 - acc: 0.8643 - val_loss: 0.2772 - val_acc: 0.9244
# Epoch 3/100
# 169/169 [==============================] - ETA: 0s - loss: 0.2295 - acc: 0.9244
# Epoch 00003: val_loss improved from 0.27718 to 0.27136, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca518.autosave.model.h5
# 169/169 [==============================] - 22s 130ms/step - loss: 0.2295 - acc: 0.9244 - val_loss: 0.2714 - val_acc: 0.9262
# Epoch 4/100
# 169/169 [==============================] - ETA: 0s - loss: 0.1359 - acc: 0.9597
# Epoch 00004: val_loss improved from 0.27136 to 0.20704, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca518.autosave.model.h5
# 169/169 [==============================] - 22s 129ms/step - loss: 0.1359 - acc: 0.9597 - val_loss: 0.2070 - val_acc: 0.9476
# Epoch 5/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0957 - acc: 0.9677
# Epoch 00005: val_loss did not improve from 0.20704
# 169/169 [==============================] - 22s 127ms/step - loss: 0.0957 - acc: 0.9677 - val_loss: 0.2190 - val_acc: 0.9413
# Epoch 6/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0709 - acc: 0.9757
# Epoch 00006: val_loss improved from 0.20704 to 0.19654, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca518.autosave.model.h5
# 169/169 [==============================] - 22s 130ms/step - loss: 0.0709 - acc: 0.9757 - val_loss: 0.1965 - val_acc: 0.9476
# Epoch 7/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0477 - acc: 0.9849
# Epoch 00007: val_loss improved from 0.19654 to 0.16490, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca518.autosave.model.h5
# 169/169 [==============================] - 22s 130ms/step - loss: 0.0477 - acc: 0.9849 - val_loss: 0.1649 - val_acc: 0.9529
# Epoch 8/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0354 - acc: 0.9870
# Epoch 00008: val_loss did not improve from 0.16490
# 169/169 [==============================] - 22s 129ms/step - loss: 0.0354 - acc: 0.9870 - val_loss: 0.2065 - val_acc: 0.9529
# Epoch 9/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0238 - acc: 0.9932
# Epoch 00009: val_loss did not improve from 0.16490
# 169/169 [==============================] - 22s 130ms/step - loss: 0.0238 - acc: 0.9932 - val_loss: 0.2471 - val_acc: 0.9502
# Epoch 10/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0303 - acc: 0.9935
# Epoch 00010: val_loss improved from 0.16490 to 0.16195, saving model to /content/drive/My Drive/FNL_TC1/Model/tc1_pca518.autosave.model.h5
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0303 - acc: 0.9935 - val_loss: 0.1620 - val_acc: 0.9582
# Epoch 11/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0190 - acc: 0.9938
# Epoch 00011: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 130ms/step - loss: 0.0190 - acc: 0.9938 - val_loss: 0.1941 - val_acc: 0.9600
# Epoch 12/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0226 - acc: 0.9938
# Epoch 00012: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 131ms/step - loss: 0.0226 - acc: 0.9938 - val_loss: 0.2308 - val_acc: 0.9449
# Epoch 13/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0177 - acc: 0.9950
# Epoch 00013: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 130ms/step - loss: 0.
100
# 169/169 [==============================] - ETA: 0s - loss: 0.0070 - acc: 0.9967
# Epoch 00078: val_loss did not improve from 0.16195
# 169/169 [==============================] - 23s 138ms/step - loss: 0.0070 - acc: 0.9967 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 79/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9997
# Epoch 00079: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 129ms/step - loss: 0.0024 - acc: 0.9997 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 80/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0036 - acc: 0.9982
# Epoch 00080: val_loss did not improve from 0.16195
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 9.999998695775504e-09.
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0036 - acc: 0.9982 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 81/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0035 - acc: 0.9991
# Epoch 00081: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0035 - acc: 0.9991 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 82/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9991
# Epoch 00082: val_loss did not improve from 0.16195
# 169/169 [==============================] - 23s 137ms/step - loss: 0.0026 - acc: 0.9991 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 83/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0051 - acc: 0.9982
# Epoch 00083: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 130ms/step - loss: 0.0051 - acc: 0.9982 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 84/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0037 - acc: 0.9988
# Epoch 00084: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0037 - acc: 0.9988 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 85/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0048 - acc: 0.9982
# Epoch 00085: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0048 - acc: 0.9982 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 86/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9997
# Epoch 00086: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 131ms/step - loss: 0.0020 - acc: 0.9997 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 87/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0036 - acc: 0.9991
# Epoch 00087: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0036 - acc: 0.9991 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 88/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0023 - acc: 0.9997
# Epoch 00088: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 131ms/step - loss: 0.0023 - acc: 0.9997 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 89/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9988
# Epoch 00089: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0038 - acc: 0.9988 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 90/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0029 - acc: 0.9991
# Epoch 00090: val_loss did not improve from 0.16195
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 9.99999905104687e-10.
# 169/169 [==============================] - 22s 133ms/step - loss: 0.0029 - acc: 0.9991 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 91/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9997
# Epoch 00091: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0024 - acc: 0.9997 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 92/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0034 - acc: 0.9985
# Epoch 00092: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 131ms/step - loss: 0.0034 - acc: 0.9985 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 93/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9985
# Epoch 00093: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0038 - acc: 0.9985 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 94/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0035 - acc: 0.9991
# Epoch 00094: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0035 - acc: 0.9991 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 95/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0033 - acc: 0.9994
# Epoch 00095: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 131ms/step - loss: 0.0033 - acc: 0.9994 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 96/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0025 - acc: 0.9994
# Epoch 00096: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0025 - acc: 0.9994 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 97/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9991
# Epoch 00097: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 133ms/step - loss: 0.0031 - acc: 0.9991 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 98/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0037 - acc: 0.9988
# Epoch 00098: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0037 - acc: 0.9988 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 99/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0039 - acc: 0.9982
# Epoch 00099: val_loss did not improve from 0.16195
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0039 - acc: 0.9982 - val_loss: 0.2421 - val_acc: 0.9627
# Epoch 100/100
# 169/169 [==============================] - ETA: 0s - loss: 0.0049 - acc: 0.9982
# Epoch 00100: val_loss did not improve from 0.16195
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 9.999998606957661e-11.
# 169/169 [==============================] - 22s 132ms/step - loss: 0.0049 - acc: 0.9982 - val_loss: 0.2421 - val_acc: 0.9627

# %%
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.24209149181842804
# Test accuracy: 0.9626666903495789

# %%
plt.plot(history.history['acc'],label="accuracy")
plt.plot(history.history['val_acc'],label="val_accuracy")
plt.plot(history.history['loss'],label="loss")
plt.plot(history.history['val_loss'],label="val_loss")
plt.legend()
plt.title("Top 300 features")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %% [markdown]
# ## Save the model/weights

# %%
# JSON JSON
# serialize model to json
json_model = model.to_json()

# save the model architecture to JSON file
with open('{}/{}.model.json'.format(output_dir, model_name), 'w') as json_file:
    json_file.write(json_model)


# YAML YAML
# serialize model to YAML
model_yaml = model.to_yaml()

# save the model architecture to YAML file
with open("{}/{}.model.yaml".format(output_dir, model_name), "w") as yaml_file:
    yaml_file.write(model_yaml)


# WEIGHTS HDF5
# serialize weights to HDF5
model.save_weights("{}/{}.model.h5".format(output_dir,model_name))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Open the handle
json_file = open('{}/{}.model.json'.format(output_dir, model_name), 'r')

# load json and create model
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights('{}/{}.model.h5'.format(output_dir, model_name))
print("Loaded model from disk")
# loaded_model_json
# Out:
# Loaded model from disk

# %%
# evaluate loaded model on test data
loaded_model.compile(loss='categorical_crossentropy', optimizer='sgd', 
                     metrics=['accuracy'])
score = loaded_model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])

print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Test score: 0.24209149181842804
# Test accuracy: 0.9626666903495789
# accuracy: 96.27%
